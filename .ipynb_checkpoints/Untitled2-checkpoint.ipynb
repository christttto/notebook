# %%
# -*- coding: utf-8 -*-
# <nbformat>3.0</nbformat>

# <codecell>

import random, time, math
import pylab as plot
import numpy as np

# <codecell>

#2c
print("2C")
print("=========================================================")
def coin_flip_7(flips, p=0.7):
    return sum([1 if random.random() < p else 0 for _ in range(flips)])

def toss(k):
    heads = coin_flip_7(k)
    plot.bar([0,1], [heads, k - heads])
    plot.show()

for t in [10, 100, 1000, 4000]:    
    toss(t)

# <codecell>

#2d
print("2D")
print("=========================================================")
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips) for _ in range (RUNS)]
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

# <codecell>

#2e
print("2E")
print("=========================================================")
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = double (results[i])/flips
    plot.axis([0,1,0,350])
    plot.hist(results)
    plot.show()

for i in [10, 100, 1000, 4000]:
    runs(i)

# <codecell>

#2f
print("2F")
print("=========================================================")
def norm(a):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(a) / float(a)
        norm_heads = 0.7 + (norm_heads - 0.7) * math.sqrt(a)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for i in [10, 100, 1000, 4000]:
    norm(i)
plot.show()

# <codecell>

#2g
print("2G")
print("=========================================================")
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips) for a in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*0.7))/sqrt(flips)
    plot.axis([-3,3,0,400])
    plot.hist(results)
    plot.show()

for i in [10, 100, 1000, 4000]:
    runs(i)
    
def q_norm(a):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(a) / float(a)
        norm_heads = 0.7 + (norm_heads - 0.7) * math.sqrt(a)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_norm(a)
plot.show()

# <codecell>

#2h when p = 0.9
print("2H")
print("=========================================================")
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips, 0.9) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.9))/sqrt(flips)
    plot.axis([-2.5,2.5,0,400])
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)
    
def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.9) / float(k)
        norm_heads = 0.9 + (norm_heads - 0.9) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#h when p = 0.6
print("=========================================================")
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips, 0.6) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.6))/sqrt(flips)
    plot.axis([-2.5,2.5,0,400])
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.6) / float(k)
        norm_heads = 0.6 + (norm_heads - 0.6) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#h when p = 0.5
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips, 0.5) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.5))/sqrt(flips)
    plot.axis([-2.5,2.5,0,400])
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.5) / float(k)
        norm_heads = 0.5 + (norm_heads - 0.5) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#h when p = 0.4
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips, 0.4) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.4))/sqrt(flips)
    plot.axis([-2.5,2.5,0,400])
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.4) / float(k)
        norm_heads = 0.4 + (norm_heads - 0.4) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#h when p =0.3
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips, 0.3) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.3))/sqrt(flips)
    plot.axis([-2.5,2.5,0,400])
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.3) / float(k)
        norm_heads = 0.3 + (norm_heads - 0.3) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#2i
quart = []
p = [.9, .6, .5, .4, .3]
y = [np.log(x*(1-x)) for x in p]
def runs(flips = 1000):
    RUNS = 1000
    for k in p:
        results = [coin_flip_7(flips, k) for _ in range (RUNS)]
        for i in range (len(results)):
            results[i] = (double(results[i])-(flips*k))/sqrt(flips)
        results.sort()
        interquartiles.append((results[flips*3/4] - results[flips*1/4]))
    plot.scatter(quart, y)
    plot.show()
runs(1000)
    

# <codecell>

#j when p = 0.9
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips,.9) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.9))/(sqrt(flips)*sqrt(.9*(1-.9)))
    plot.hist(results)
    plot.show()

for i in [10, 100, 1000, 4000]:
    runs(i)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.9) / float(k)
        norm_heads = 0.9 + (norm_heads - 0.9) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for i in [10, 100, 1000, 4000]:
    q_curve_norm(i)
plot.show()

# <codecell>

#j when p = 0.6
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips,.6) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.6))/(sqrt(flips)*sqrt(.6*(1-.6)))
    plot.hist(results)
    plot.show()

for i in [10, 100, 1000, 4000]:
    runs(i)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.6) / float(k)
        norm_heads = 0.6 + (norm_heads - 0.6) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for i in [10, 100, 1000, 4000]:
    q_curve_norm(i)
plot.show()

# <codecell>

#j when p = 0.5
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips,.5) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.5))/(sqrt(flips)*sqrt(.5*(1-.5)))
    plot.hist(results)
    plot.show()

for i in [10, 100, 1000, 4000]:
    runs(i)

def q_curve_norm(r):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.5) / float(k)
        norm_heads = 0.5 + (norm_heads - 0.5) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#j when p = 0.4
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips,.4) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.4))/(sqrt(flips)*sqrt(.4*(1-.4)))
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.4) / float(k)
        norm_heads = 0.4 + (norm_heads - 0.4) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#j when p = 0.3
def runs(flips):
    RUNS = 1000
    results = [coin_flip_7(flips,.3) for _ in range (RUNS)]
    for i in range (len(results)):
        results[i] = (double (results[i])-(flips*.3))/(sqrt(flips)*sqrt(.3*(1-.3)))
    plot.hist(results)
    plot.show()

for r in [10, 100, 1000, 4000]:
    runs(r)

def q_curve_norm(k):
    RUNS = 1000
    def head():
        norm_heads = coin_flip_7(k,0.3) / float(k)
        norm_heads = 0.3 + (norm_heads - 0.3) * math.sqrt(k)
        return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))

for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>

#2k
d_neg = -3
d_pos = 3
p = [0.9, 0.6, 0.5, 0.4, 0.3]
range_d = []
def runs(flips):
    RUNS = 1000
    for k in p:
        results = [coin_flip_7(flips, k) for _ in range (RUNS)]
        for i in range (len(results)):
            results[i] = (double (results[i])-(flips*k))/(sqrt(flips)*sqrt(k*(1-k)))
            if results[i] < d_neg or results[i] > d_pos:
                range_d.append(results[i])
    plot.hist(range_d)
    plot.show()

runs(10)

# <codecell>

#j (trial # 2)
p = [0.9, 0.6, 0.5, 0.4, 0.3]
def q_curve_norm(k):
    RUNS = 1000
    def head():
        for i in p:
            norm_heads = coin_flip_7(k) / float(k)
            norm_heads = i + (norm_heads - i) * math.sqrt(k)
            return norm_heads
    heads = [head() for _ in range(RUNS)]
    heads.sort()
    plot.plot(heads, list(range(1, RUNS + 1)))


for k in [10, 100, 1000, 4000]:
    q_curve_norm(k)
plot.show()

# <codecell>
# Out:
# 2C
# ...
# 2D
# ...
# 2E
# ...
# 2F
# ...
# 2G
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7eece4d55532> in <module>()
#     102
#     103 for k in [10, 100, 1000, 4000]:
# --> 104     q_norm(a)
#     105 plot.show()
#     106
#
# NameError: name 'a' is not defined
